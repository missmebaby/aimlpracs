# %%
# !pip install pyspellchecker -q

# %%
import pandas as pd
import re
import nltk
import spacy
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from tabulate import tabulate
from nltk.corpus import wordnet as wn
from spellchecker import SpellChecker
from nltk.stem import PorterStemmer, WordNetLemmatizer
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# # Load the Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/Datasets/mtsamples.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0   A 23-year-old white female presents with comp...
# 1           1           Consult for laparoscopic gastric bypass.
# 2           2           Consult for laparoscopic gastric bypass.
# 3           3                             2-D M-Mode. Doppler.
# 4           4                                 2-D Echocardiogram
#
#              medical_specialty                                sample_name  \
# 0         Allergy / Immunology                         Allergic Rhinitis
# 1                   Bariatrics   Laparoscopic Gastric Bypass Consult - 2
# 2                   Bariatrics   Laparoscopic Gastric Bypass Consult - 1
# 3   Cardiovascular / Pulmonary                    2-D Echocardiogram - 1
# 4   Cardiovascular / Pulmonary                    2-D Echocardiogram - 2
#
#                                        transcription  \
# 0  SUBJECTIVE:,  This 23-year-old white female pr...
# 1  PAST MEDICAL HISTORY:, He has difficulty climb...
# 2  HISTORY OF PRESENT ILLNESS: , I have seen ABC ...
# 3  2-D M-MODE: , ,1.  Left atrial enlargement wit...
# 4  1.  The left ventricular cavity size and wall ...
#
#                                             keywords
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...

# %% [markdown]
# # Data Preparation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4999 non-null   int64
#  1   description        4999 non-null   object
#  2   medical_specialty  4999 non-null   object
#  3   sample_name        4999 non-null   object
#  4   transcription      4966 non-null   object
#  5   keywords           3931 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 234.5+ KB

# %%
df = df.dropna(subset=['transcription'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4966 entries, 0 to 4998
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         4966 non-null   int64
#  1   description        4966 non-null   object
#  2   medical_specialty  4966 non-null   object
#  3   sample_name        4966 non-null   object
#  4   transcription      4966 non-null   object
#  5   keywords           3898 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.6+ KB

# %% [markdown]
# # Data Cleaning

# %%
def remove_special_characters(text):
    remove_special = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    return ''.join(remove_special)

# %%
for col in df:
  if col!= 'Unnamed: 0' and col!= 'keywords':
    df[col] = df[col].apply(remove_special_characters)

# %%
df.head()
# Out:
#    Unnamed: 0                                        description  \
# 0           0   A 23yearold white female presents with compla...
# 1           1            Consult for laparoscopic gastric bypass
# 2           2            Consult for laparoscopic gastric bypass
# 3           3                                 2D MMode Doppler
# 4           4                                  2D Echocardiogram
#
#             medical_specialty                               sample_name  \
# 0         Allergy  Immunology                        Allergic Rhinitis
# 1                  Bariatrics   Laparoscopic Gastric Bypass Consult  2
# 2                  Bariatrics   Laparoscopic Gastric Bypass Consult  1
# 3   Cardiovascular  Pulmonary                     2D Echocardiogram  1
# 4   Cardiovascular  Pulmonary                     2D Echocardiogram  2
#
#                                        transcription  \
# 0  SUBJECTIVE  This 23yearold white female presen...
# 1  PAST MEDICAL HISTORY He has difficulty climbin...
# 2  HISTORY OF PRESENT ILLNESS  I have seen ABC to...
# 3  2D MMODE  1  Left atrial enlargement with left...
# 4  1  The left ventricular cavity size and wall t...
#
#                                             keywords
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...

# %% [markdown]
# # Text Preprocessing

# %%
spell = SpellChecker()
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

def text_preprocessing(text):
    # Tokenization
    words = word_tokenize(text)

    # Lowercasing and removing punctuation
    words = [re.sub(r'[^\w\s]', '', word.lower()) for word in words]

    # Stop word removal
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Stemming
    words = [lemmatizer.lemmatize(word) for word in words]

    return ' '.join(words)

# %%
for col in df:
  if col!= 'Unnamed: 0' and col!= 'keywords':
    df[col] = df[col].apply(text_preprocessing)

# %%
df.head()
# Out:
#    Unnamed: 0                                       description  \
# 0           0  23yearold white female present complaint allergy
# 1           1               consult laparoscopic gastric bypass
# 2           2               consult laparoscopic gastric bypass
# 3           3                                  2d mmode doppler
# 4           4                                 2d echocardiogram
#
#           medical_specialty                            sample_name  \
# 0        allergy immunology                      allergic rhinitis
# 1                bariatrics  laparoscopic gastric bypass consult 2
# 2                bariatrics  laparoscopic gastric bypass consult 1
# 3  cardiovascular pulmonary                    2d echocardiogram 1
# 4  cardiovascular pulmonary                    2d echocardiogram 2
#
#                                        transcription  \
# 0  subjective 23yearold white female present comp...
# 1  past medical history difficulty climbing stair...
# 2  history present illness seen abc today pleasan...
# 3  2d mmode 1 left atrial enlargement left atrial...
# 4  1 left ventricular cavity size wall thickness ...
#
#                                             keywords
# 0  allergy / immunology, allergic rhinitis, aller...
# 1  bariatrics, laparoscopic gastric bypass, weigh...
# 2  bariatrics, laparoscopic gastric bypass, heart...
# 3  cardiovascular / pulmonary, 2-d m-mode, dopple...
# 4  cardiovascular / pulmonary, 2-d, doppler, echo...

# %% [markdown]
# # NER

# %%
# !pip install -U spacy
# !pip install scispacy

# %%
# !pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_ner_bc5cdr_md-0.5.1.tar.gz -q

# %%
# !pip install render -q

# %%
import scispacy
import spacy
import en_ner_bc5cdr_md
from spacy import displacy
import pandas as pd

# %%
nlp_bc = en_ner_bc5cdr_md.load()
doc = nlp_bc(df['transcription'][2])
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">history present
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     illness
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  seen abc today pleasant gentleman 42 year old 344 pound 59 bmi 51 overweight ten year since age 33 highest 358 pound lowest 260 pursuing surgical attempt
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weight loss
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  feel good get healthy begin exercise want able exercise play volleyball physically sluggish get tired quickly go often loses weight always regains gain back lost biggest weight loss 25 pound three month gained back six month drinking
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alcohol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  taking many calorie multiple commercial
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     weight loss
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  program including slim fast one month one year ago atkins diet one month two year agopast medical history difficulty climbing stair difficulty airline seat tying shoe used public seating difficulty walking high
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cholesterol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  high blood pressure
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     asthma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  difficulty walking two block going eight ten step
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sleep apnea snoring diabetic medication joint pain knee pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  back
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  foot
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ankle pain
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  leg foot swelling hemorrhoidspast surgical history includes orthopedic knee surgerysocial history currently single drink
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     alcohol
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  ten twelve drink week drink five day week binge drink
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     smoke
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  one half pack day 15 year recently stopped smoking past two weeksfamily history obesity
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     heart disease diabetes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  family history negative
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  strokecurrent medication include
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     diovan
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  crestor tricormiscellaneouseating history say couple friend heart attack died used drink everyday stopped two year ago drink weekend second week chantix medication come smoking completely eating eats bad food single eats thing like bacon egg cheese cheeseburger fast food eats four time day seven morning noon 9 pm 2 currently weighs 344 pound 59 ideal body weight 160 pound 184 pound overweight lost 70 excess body weight would 129 pound would get 215review system negative head neck heart lung gi gu orthopedic skin also positive
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     gout
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  denies
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     chest pain heart attack coronary artery disease congestive heart failure arrhythmia atrial fibrillation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  pacemaker
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pulmonary embolism
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  cva denies
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     venous insufficiency thrombophlebitis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  denies
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     shortness breath copd emphysema
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  denies thyroid problem hip
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pain osteoarthritis rheumatoid arthritis gerd hiatal hernia peptic ulcer disease gallstone infected gallbladder pancreatitis

# %%
doc = nlp_bc(df['transcription'][4])
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">1 left ventricular cavity size wall thickness appear normal wall motion left ventricular systolic function appears hyperdynamic estimated ejection fraction 70 75 nearcavity obliteration seen also appears increased left ventricular outflow tract gradient mid cavity level consistent hyperdynamic left ventricular systolic function abnormal left ventricular relaxation pattern seen well elevated left atrial pressure seen doppler examination2 left atrium appears mildly dilated3 right atrium right ventricle appear normal4 aortic root appears normal5 aortic valve appears calcified mild
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aortic valve stenosis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  calculated aortic valve area 13 cm square maximum instantaneous gradient 34 mean gradient 19 mm6 mitral annular
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     calcification
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  extending leaflet supportive structure thickening mitral valve leaflet mild mitral regurgitation7 tricuspid valve appears normal trace
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     tricuspid regurgitation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  moderate
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     pulmonary artery hypertension
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  estimated pulmonary artery systolic pressure 49 mmhg estimated right atrial pressure 10 mmhg8 pulmonary valve appears normal trace pulmonary insufficiency9 pericardial effusion
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     intracardiac mass seen10 color doppler suggestive patent foramen ovale lipomatous hypertrophy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  interatrial septum11 study somewhat technically limited hence subtle abnormality could missed study</div></span>

# %%
doc = nlp_bc(df['transcription'][26])
displacy_image = displacy.render(doc, jupyter=True,style='ent')
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">procedure cystourethroscopy transurethral resection prostatecomplications noneadmitting diagnosis difficulty voidinghistory 67year old hispanic male patient admitted enlarged
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prostate symptom bladder neck obstruction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  physical examination revealed normal heart lung abdomen negative abnormal finding laboratory data bun 19
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     creatinine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  11 blood group rh positive hemoglobin 13 hematocrit 321 prothrombin time 126 second ptt 371 discharge hemoglobin 114 hematocrit 333 chest xray calcified old
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     granulomatous disease
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  otherwise normal ekg normal course hospital patient
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     cysto tur prostate
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  postoperative course uncomplicated pathology report pending time dictation discharged satisfactory condition good urinary stream minimal hematuria
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bactrim
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CHEMICAL</span>
# </mark>
#  d one day ten day standard postprostatic surgery instruction sheet discharge diagnosis enlarged
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prostate benign bladder neck obstruction
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DISEASE</span>
# </mark>
#  followed office one week dr abc next available outpatient</div></span>

# %%
examples = []
for i in range(5):
  doc = nlp_bc(df['transcription'][i])
  for ent in doc.ents:
    examples.append((ent.text,[(ent.start_char, ent.end_char, ent.label_)]))

# %%
examples
# Out:
# [('allergy', [(52, 59, 'DISEASE')]),
#  ('allergy', [(65, 72, 'DISEASE')]),
#  ('asthma', [(301, 307, 'DISEASE')]),
#  ('throat', [(504, 510, 'DISEASE')]),
#  ('loratadine', [(730, 740, 'CHEMICAL')]),
#  ('muscle joint pain', [(226, 243, 'DISEASE')]),
#  ('knee pain', [(254, 263, 'DISEASE')]),
#  ('pain', [(269, 273, 'DISEASE')]),
#  ('ankle pain swelling gastroesophageal reflux diseasepast',
#   [(279, 334, 'DISEASE')]),
#  ('smoke', [(493, 498, 'CHEMICAL')]),
#  ('heart disease', [(536, 549, 'DISEASE')]),
#  ('grandmother stroke grandmother diabetes denies obesity hypertension',
#   [(562, 629, 'DISEASE')]),
#  ('allergic', [(677, 685, 'DISEASE')]),
#  ('chest pain', [(1170, 1180, 'DISEASE')]),
#  ('coronary artery disease congestive heart failure arrhythmia',
#   [(1194, 1253, 'DISEASE')]),
#  ('atrial fibrillation', [(1254, 1273, 'DISEASE')]),
#  ('cholesterol', [(1289, 1300, 'CHEMICAL')]),
#  ('venous insufficiency thrombophlebitis asthma shortness breath copd emphysema sleep apnea diabetes leg foot swelling osteoarthritis rheumatoid arthritis hiatal hernia peptic ulcer disease gallstone infected gallbladder pancreatitis fatty liver hepatitis hemorrhoid rectal bleeding polyp incontinence stool urinary stress incontinence cancer',
#   [(1344, 1683, 'DISEASE')]),
#  ('cellulitis pseudotumor cerebri meningitis', [(1691, 1732, 'DISEASE')]),
#  ('illness', [(16, 23, 'DISEASE')]),
#  ('weight loss', [(178, 189, 'DISEASE')]),
#  ('alcohol', [(424, 431, 'CHEMICAL')]),
#  ('weight loss', [(472, 483, 'DISEASE')]),
#  ('cholesterol', [(695, 706, 'CHEMICAL')]),
#  ('asthma', [(727, 733, 'DISEASE')]),
#  ('sleep apnea snoring diabetic medication joint pain knee pain',
#   [(784, 844, 'DISEASE')]),
#  ('pain', [(850, 854, 'DISEASE')]),
#  ('ankle pain', [(860, 870, 'DISEASE')]),
#  ('alcohol', [(992, 999, 'CHEMICAL')]),
#  ('smoke', [(1054, 1059, 'CHEMICAL')]),
#  ('heart disease diabetes', [(1148, 1170, 'DISEASE')]),
#  ('hypertension', [(1195, 1207, 'DISEASE')]),
#  ('diovan', [(1241, 1247, 'CHEMICAL')]),
#  ('gout', [(1780, 1784, 'DISEASE')]),
#  ('chest pain heart attack coronary artery disease congestive heart failure arrhythmia atrial fibrillation',
#   [(1792, 1895, 'DISEASE')]),
#  ('pulmonary embolism', [(1906, 1924, 'DISEASE')]),
#  ('venous insufficiency thrombophlebitis', [(1936, 1973, 'DISEASE')]),
#  ('shortness breath copd emphysema', [(1981, 2012, 'DISEASE')]),
#  ('pain osteoarthritis rheumatoid arthritis gerd hiatal hernia peptic ulcer disease gallstone infected gallbladder pancreatitis fatty liver hepatitis rectal bleeding polyp incontinence stool urinary stress incontinence cancer',
#   [(2040, 2262, 'DISEASE')]),
#  ('cellulitis pseudotumor cerebri meningitis', [(2270, 2311, 'DISEASE')]),
#  ('wheezing', [(2422, 2430, 'DISEASE')]),
#  ('pitting', [(2494, 2501, 'DISEASE')]),
#  ('bleeding infection', [(2603, 2621, 'DISEASE')]),
#  ('venous thrombosis pulmonary embolism leakage', [(2627, 2671, 'DISEASE')]),
#  ('bowel obstruction', [(2729, 2746, 'DISEASE')]),
#  ('function5', [(184, 193, 'CHEMICAL')]),
#  ('aortic valve mitral valve tricuspid valve pulmonary valve7 pa systolic pressure 36 mmhgdoppler',
#   [(234, 328, 'DISEASE')]),
#  ('pulmonary regurgitation', [(381, 404, 'DISEASE')]),
#  ('aortic valve stenosis', [(585, 606, 'DISEASE')]),
#  ('calcification', [(719, 732, 'DISEASE')]),
#  ('tricuspid regurgitation', [(868, 891, 'DISEASE')]),
#  ('pulmonary artery hypertension', [(901, 930, 'DISEASE')]),
#  ('intracardiac mass seen10 color doppler suggestive patent foramen ovale lipomatous hypertrophy',
#   [(1108, 1201, 'DISEASE')])]

# %%
from spacy.scorer import Scorer
from spacy.tokens import Doc
from spacy.training.example import Example

def evaluate(ner_model, examples):
    scorer = Scorer()
    example = []
    for input_, annot in examples:
        pred = ner_model(input_)
        temp = Example.from_dict(pred, dict.fromkeys(annot))
        example.append(temp)
    scores = scorer.score(example)
    return scores

results = evaluate(nlp_bc, examples)
print(results)
# Out:
# {'token_acc': 1.0, 'token_p': 1.0, 'token_r': 1.0, 'token_f': 1.0, 'sents_p': 1.0, 'sents_r': 1.0, 'sents_f': 1.0, 'tag_acc': None, 'pos_acc': None, 'morph_acc': None, 'morph_micro_p': None, 'morph_micro_r': None, 'morph_micro_f': None, 'morph_per_feat': None, 'dep_uas': None, 'dep_las': None, 'dep_las_per_type': None, 'ents_p': None, 'ents_r': None, 'ents_f': None, 'ents_per_type': None, 'cats_score': 0.0, 'cats_score_desc': 'macro F', 'cats_micro_p': 0.0, 'cats_micro_r': 0.0, 'cats_micro_f': 0.0, 'cats_macro_p': 0.0, 'cats_macro_r': 0.0, 'cats_macro_f': 0.0, 'cats_macro_auc': 0.0, 'cats_f_per_type': {}, 'cats_auc_per_type': {}}
